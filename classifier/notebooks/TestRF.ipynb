# %%
import pandas as pd

# %%
testdf = pd.read_csv("/home/burak/Downloads/cydec.csv",sep=";")

# %%
testdf
# Out:
#                Unnamed: 0                                             tweets  \
# 0      907992283076755456  ddos attacks on internet providers can impact ...
# 1      898978582432579584  $mention$ new malware masquerades as rideshari...
# 2      880183959174471680  that thing where you run corporation phishing ...
# 3      872130114884165632  operators beware ddos attackslarge and smallke...
# 4      832354396977524736  transcend vr sues investor mike rothenberg for...
# ...                   ...                                                ...
# 10997                 NaN                                                NaN
# 10998                 NaN                                                NaN
# 10999                 NaN                                                NaN
# 11000                 NaN                                                NaN
# 11001                 NaN                                                NaN
#
#        final validation
# ...
